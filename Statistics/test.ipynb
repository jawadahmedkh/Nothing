# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate random normal data
data = np.random.normal(loc=0, scale=1, size=1000)  # mean=0, SD=1

# Plot
plt.figure(figsize=(8,5))
plt.hist(data, bins=30, density=True, alpha=0.6, color='skyblue')
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, 0, 1)
plt.plot(x, p, 'k', linewidth=2)
plt.title('Normal Distribution (Mean=0, SD=1)')
plt.xlabel('Data values')
plt.ylabel('Probability Density')
plt.show()

# %%
import requests
from bs4 import BeautifulSoup

# Example: Collect titles from a web page
url = "https://chatgpt.com/c/6814762d-f4a4-800e-b3bd-dfc2a35ae8cb"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract and print all titles
for title in soup.find_all('h1'):
    print(title.text)
